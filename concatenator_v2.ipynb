# %%
import os

# %%
genotype = "B3.2"
start_date = "11-01-2021"
end_date = "12-05-2025"

date_range = start_date + "--" + end_date

# input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/" + date_range + "/" + genotype + "/trimmed/"
# input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/"
# input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/"
input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/" + date_range + "/" + genotype + "/trimmed/"
# input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--11-14-2025_Antarctica_North_America_South_America/unassigned/"


os.chdir(input_path)
sequences = {}
isolates = {}

# duplicates = {}
# output_path = input_path + "concat.fasta" # Genotype and Segment should all be the same


for dirpath, dirs, files in os.walk(input_path):
    counter = 0
    # current_header = ""
    
    for file in files:
        
        print(counter)
        file_name = os.path.join(dirpath, file)
        print(file_name)
        
        # sequences[header] = "" # Put header in list of headers to get sequences
        
        
        with open(file_name) as f:
            lines = f.readlines()
            header = ""
            isolate = ""
            for l in lines:
                # already_an_instance = False
                if l[0] == ">": # If header
                    header = l
                    isolate = header.split("|")[1]
                    if counter == 0: # and isolate in isolates.keys():

                        isolates[isolate] = header # Add isolate to list of seen isolates
                        sequences[header] = ""

                else: # If sequence
                    sequence = l
                    try:
                        sequences[header] = sequences[header] + sequence
                    except: # It's an NCBI Virus sequence whose header doesn't match the previous
                        if isolate in isolates.keys():
                            sequences[isolates[isolate]] = sequences[isolates[isolate]] + sequence
                        else:
                            print(header)
            f.close()
        counter += 1
    break 

print(sequences.keys())
print(len(sequences)) # There are different identifiers for each segment in NCBI Virus

# print(len(set(list(sequences.keys()))))

with open(input_path + genotype + "_concat_" + str(len(sequences)) + ".fasta", "w+") as o:
    for header in sequences.keys():
        # if header != "no":
        sequence = sequences[header]
        o.write(header + "\n")
        o.write(sequence + "\n")
    o.close()
# Out:
# 0
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--12-05-2025/B3.2/trimmed/1-all_B3.2_PB2_11-01-2021--12-05-2025_aln_trimmed.fasta
# 1
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--12-05-2025/B3.2/trimmed/2-all_B3.2_PB1_11-01-2021--12-05-2025_aln_trimmed.fasta
# 2
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--12-05-2025/B3.2/trimmed/3-all_B3.2_PA_11-01-2021--12-05-2025_aln_trimmed.fasta
# 3
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--12-05-2025/B3.2/trimmed/4-all_B3.2_HA_11-01-2021--12-05-2025_aln_trimmed.fasta
# 4
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--12-05-2025/B3.2/trimmed/5-all_B3.2_NP_11-01-2021--12-05-2025_aln_trimmed.fasta
# 5
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--12-05-2025/B3.2/trimmed/6-all_B3.2_NA_11-01-2021--12-05-2025_aln_trimmed.fasta
# 6
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--12-05-2025/B3.2/trimmed/7-all_B3.2_MP_11-01-2021--12-05-2025_aln_trimmed.fasta
# 7
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021