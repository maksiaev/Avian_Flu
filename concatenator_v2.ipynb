# %%
import os

# %%
genotype = "D1.3"
start_date = "11-01-2021"
end_date = "03-06-2026"

date_range = start_date + "--" + end_date

# input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/" + date_range + "/" + genotype + "/trimmed/"
# input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/"
# input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/"
# input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/" + date_range + "/" + genotype + "/trimmed/"
# input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--11-14-2025_Antarctica_North_America_South_America/unassigned/"
input_path = "C:/Users/maksiaevai.NCBI_NT/OneDrive - National Institutes of Health/Documents/Virus_Evolution/Avian_Flu_Files/Alignments/" + date_range + "/" + genotype + "/"

os.chdir(input_path)
sequences = {}
isolates = {}

# duplicates = {}
# output_path = input_path + "concat.fasta" # Genotype and Segment should all be the same


for dirpath, dirs, files in os.walk(input_path):
    counter = 0
    # current_header = ""
    
    for file in files:
        
        print(counter)
        file_name = os.path.join(dirpath, file)
        print(file_name)
        
        # sequences[header] = "" # Put header in list of headers to get sequences
        
        
        with open(file_name) as f:
            lines = f.readlines()
            header = ""
            isolate = ""
            for l in lines:
                # already_an_instance = False
                if l[0] == ">": # If header
                    header = l
                    isolate = header.split("|")[1]
                    if counter == 0: # and isolate in isolates.keys():

                        isolates[isolate] = header # Add isolate to list of seen isolates
                        sequences[header] = ""

                else: # If sequence
                    sequence = l
                    try:
                        sequences[header] = sequences[header] + sequence
                    except: # It's an NCBI Virus sequence whose header doesn't match the previous
                        if isolate in isolates.keys():
                            sequences[isolates[isolate]] = sequences[isolates[isolate]] + sequence
                        else:
                            print(header)
            f.close()
        counter += 1
    break 

print(sequences.keys())
print(len(sequences)) # There are different identifiers for each segment in NCBI Virus

# print(len(set(list(sequences.keys()))))

with open(input_path + genotype + "_concat_" + str(len(sequences)) + ".fasta", "w+") as o:
    for header in sequences.keys():
        # if header != "no":
        sequence = sequences[header]
        o.write(header + "\n")
        o.write(sequence + "\n")
    o.close()
# Out:
# 0
# C:/Users/maksiaevai.NCBI_NT/OneDrive - National Institutes of Health/Documents/Virus_Evolution/Avian_Flu_Files/Alignments/11-01-2021--03-06-2026/D1.3/1-D1.3_PB2_11-01-2021--03-06-2026_aln_trim.fasta
# 1
# C:/Users/maksiaevai.NCBI_NT/OneDrive - National Institutes of Health/Documents/Virus_Evolution/Avian_Flu_Files/Alignments/11-01-2021--03-06-2026/D1.3/2-D1.3_PB1_11-01-2021--03-06-2026_aln_trim.fasta
# 2
# C:/Users/maksiaevai.NCBI_NT/OneDrive - National Institutes of Health/Documents/Virus_Evolution/Avian_Flu_Files/Alignments/11-01-2021--03-06-2026/D1.3/3-D1.3_PA_11-01-2021--03-06-2026_aln_trim.fasta
# 3
# C:/Users/maksiaevai.NCBI_NT/OneDrive - National Institutes of Health/Documents/Virus_Evolution/Avian_Flu_Files/Alignments/11-01-2021--03-06-2026/D1.3/4-D1.3_HA_11-01-2021--03-06-2026_aln_trim.fasta
# 4
# C:/Users/maksiaevai.NCBI_NT/OneDrive - National Institutes of Health/Documents/Virus_Evolution/Avian_Flu_Files/Alignments/11-01-2021--03-06-2026/D1.3/5-D1.3_NP_11-01-2021--03-06-2026_aln_trim.fasta
# 5
# C:/Users/maksiaevai.NCBI_NT/OneDrive - National Institutes of Health/Documents/Virus_Evolution/Avian_Flu_Files/Alignments/11-01-2021--03-06-2026/D1.3/6-D1.3_NA_11-01-2021--03-06-2026_aln_trim.fasta
# 6
# C:/Users/maksiaevai.NCBI_NT/OneDrive - National Institutes of Health/Documents/Virus_Evolution/Avian_Flu_Files/Alignments/11-01-2021--03-06-2026/D1.3/7-D1.3_MP_11-01-2021--03-06-2026_aln_trim.fasta
# 7
# C:/Users/maksiaevai.NCBI_NT/OneDrive - National Institutes of Health/Documents/Virus_Evolution/Avian_Flu_Files/Alignments/11-01-2021--03-06-2026/D1.3/8-D1.3_NS_11-01-2021--03-06-2026_aln_trim.fasta
# dict_keys(['>EPI_ISL_19793724|A/Ostrich/BC/FAV-0003-02/2025|H5N1|Canada-BC|2024-12-30|domestic_avian|D1.3\n', '>EPI_ISL_19737284|A/turkey/USA/001676-001/2025|H5N1|USA|2025|domestic_avian|D1.3\n', '>EPI_ISL_19777113|A/turkey/USA/002648-001/2025|H5N1|USA|2025|domestic_avian|D1.3\n', '>EPI_ISL_19785793|A/Ohio/06-1/2025|H5N1|USA-OH|2025-02-12|human|D1.3\n', '>EPI_ISL_19820828|A/turkey/USA/005336-002-R2/2025|H5N1|USA|2025|domestic_avian|D1.3\n', '>EPI_ISL_19756103|A/turkey/USA/005337-002/2025|H5N1|USA|2025|domestic_avian|D1.3\n', '>SRR32254505|A/turkey/United_States/25-002414-001/2025||USA-OH|2025-01-22|domestic_avian|D1.3|Mercer_County_OH|Wayne_Jones\n', '>SRR32254524|A/chicken/United_States/25-002299-002/2025||USA|2025|domestic_avian|D1.3\n', '>SRR32254525|A/chicken/United_States/25-002299-001/2025||USA|2025|domestic_avian|D1.3\n', '>SRR32254527|A/turkey/United_States/25-002298-002/2025||US