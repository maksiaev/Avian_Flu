# %%
import os

# %%
genotype = "B3.2"
# start_date = "11-01-2021"
# end_date = "08-15-2025"

# date_range = start_date + "--" + end_date

# input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/" + date_range + "/" + genotype + "/trimmed/"
# input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/"
input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/"

os.chdir(input_path)
sequences = {}

# output_path = input_path + "concat.fasta" # Genotype and Segment should all be the same

for dirpath, dirs, files in os.walk(input_path):
    for file in files:
        file_name = os.path.join(dirpath, file)
        print(file_name)
        header = ""
        with open(file_name) as f:
            lines = f.readlines()
            lines_list = []
            for line in lines:
                lines_list.append(line)
            for i, l in enumerate(lines_list):
                if l[0] == ">": # If header
                    header = l
                    if header not in sequences.keys():
                        sequences[header] = ""
                else: # If sequence
                    sequence = l
                    sequences[header] = sequences[header] + sequence
            f.close()
    break 

print(sequences.keys())

with open(input_path + genotype + "_concat_" + str(len(sequences)) + ".fasta", "w+") as o:
    for header in sequences:
        sequence = sequences[header]
        o.write(header + "\n")
        o.write(sequence + "\n")
    o.close()
# Out:
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/1-B3_2_PB2_Nov12021_Oct32025_Antarctica_South_America_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/2-B3_2_PB1_Nov12021_Oct32025_Antarctica_South_America_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/3-B3_2_PA_Nov12021_Oct32025_Antarctica_South_America_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/4-B3_2_HA_Nov12021_Oct32025_Antarctica_South_America_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/5-B3_2_NP_Nov12021_Oct32025_Antarctica_South_America_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/6-B3_2_NA_Nov12021_Oct32025_Antarctica_South_America_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/7-B3_2_MP_Nov12021_Oct32025_Antarctica_South_America_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/8-B3_2_NS_Nov12021_Oct32025_Antarctica_South_America_aln.fasta
# dict_keys(['>EPI_ISL_18698525|A/Chicken/Argentina/2305-6/2023|H5N1|Argentina|2023-05-18|domestic_avian|B3.2\n', '>EPI_ISL_18698524|A/Chicken/Argentina/2305-1/2023|H5N1|Argentina|2023-05-18|domestic_avian|B3.2\n', '>EPI_ISL_18698526|A/Chicken/Argentina/2483-3/2023|H5N1|Argentina|2023-05-29|domestic_avian|B3.2\n', '>EPI_ISL_18698516|A/Avian/Argentina/1762-2/2023|H5N1|Argentina|2023-04-21|wild_avian|B3.2\n', '>EPI_ISL_18698511|A/Chicken/Argentina/1530-3/2023|H5N1|Argentina|2023-04-12|domestic_avian|B3.2\n', '>EPI_ISL_18698506|A/Chicken/Argentina/1200-1/2023|H5N1|Argentina|2023-03-27|domestic_avian|B3.2\n', '>EPI_ISL_18698497|A/Turkey/Argentina/753-1/2023|H5N1|Argentina|2023-03-04|domestic_avian|B3.2\n', '>EPI_ISL_18698474|A/Chicken/Argentina/506-2/2023|H5N1|Argentina|2023-02-20|domestic_avian|B3.2\n', '>EPI_ISL_18698478|A/Chicken/Argentina/556-6/2023|H5N1|Argentina|2023-02-23|domestic_avian|B3.2\n', '>EPI_ISL_18310963|A/backyard_chicken/Uruguay/UDELAR-127-M1/2023|H5N1|Uruguay|2023-04-17|domestic_avian|B3.2\n', '>EPI_ISL_18310962|A/backyard_chicken/Uruguay/UDELAR-127-M4/2023|H5N1|Uruguay|2023-04-17|domestic_avian|B3.2\n', '>EPI_ISL_18698518|A/Chicken/Argentina/1976-2/2023|H5N1|Argentina|2023-05-01|domestic_avian|B3.2\n', '>EPI_ISL_19765485|A/Nasua_nasua/Uruguay/146M1/2023|H5N1|Uruguay|2023-05-05|other_mammal|B3.2\n', '>EPI_ISL_19765475|A/Nasua_nasua/Uruguay/145M2/2023|H5N1|Uruguay|2