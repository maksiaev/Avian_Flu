# %%
import os

# %%
genotype = "D1.1"
# start_date = "11-01-2021"
# end_date = "08-15-2025"

# date_range = start_date + "--" + end_date

# input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/" + date_range + "/" + genotype + "/trimmed/"
input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/"
# input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/"

os.chdir(input_path)
sequences = {}

# output_path = input_path + "concat.fasta" # Genotype and Segment should all be the same

for dirpath, dirs, files in os.walk(input_path):
    for file in files:
        file_name = os.path.join(dirpath, file)
        print(file_name)
        header = ""
        with open(file_name) as f:
            lines = f.readlines()
            lines_list = []
            for line in lines:
                lines_list.append(line)
            for i, l in enumerate(lines_list):
                if l[0] == ">": # If header
                    header = l
                    if header not in sequences.keys():
                        sequences[header] = ""
                else: # If sequence
                    sequence = l
                    sequences[header] = sequences[header] + sequence
            f.close()
    break 

print(sequences.keys())

with open(input_path + genotype + "_concat_" + str(len(sequences)) + ".fasta", "w+") as o:
    for header in sequences:
        sequence = sequences[header]
        o.write(header + "\n")
        o.write(sequence + "\n")
    o.close()
# Out:
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/all_D1.1_HA_11-01-2021--09-19-2025_edit_wendy_data.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/all_D1.1_MP_11-01-2021--09-19-2025_edit_wendy_data.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/all_D1.1_NA_11-01-2021--09-19-2025_edit_wendy_data.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/all_D1.1_NP_11-01-2021--09-19-2025_edit_wendy_data.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/all_D1.1_NS_11-01-2021--09-19-2025_edit_wendy_data.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/all_D1.1_PA_11-01-2021--09-19-2025_edit_wendy_data.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/all_D1.1_PB1_11-01-2021--09-19-2025_edit_wendy_data.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/all_D1.1_PB2_11-01-2021--09-19-2025_edit_wendy_data.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/B3.2_concat_3179.fasta
# dict_keys(['>SRR32254506|A/chicken/United_States/25-002402-010/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254507|A/chicken/United_States/25-002402-009/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254508|A/chicken/United_States/25-002402-008/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254509|A/chicken/United_States/25-002402-007/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254510|A/chicken/United_States/25-002402-006/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254511|A/chicken/United_States/25-002402-005/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254512|A/chicken/United_States/25-002402-004/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254513|A/chicken/United_States/25-002402-003/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254514|A/chicken/United_States/25-002402-002/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254515|A/chicken/United_States/25-001670-006/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254516|A/chicken/United_States/25-002402-001/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254517|A/chicken/United_States/25-002311-002/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254518|A/chicken/United_States/25-002311-001/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254519|A/chicken/United_States/25-002306-002/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254520|A/chicken/United_States/25-002306-001/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254521|A/turkey/United_States/25-002303-003/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254522|A/turkey/United_States/25-002303-002/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254523|A/turkey/United_States/25-002303-001/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254526|A/chicken/United_States/25-001670-005/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254536|A/chicken/United_States/25-002293-002/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254537|A/chicken/United_States/25-001670-004/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254538|A/chicken/United_States/25-002293-001/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254539|A/chicken/United_States/25-002292-002/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254541|A/chicken/United_States/25-002290-004/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254542|A/chicken/United_States/25-002290-003/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254543|A/chicken/United_States/25-002290-002/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254544|A/chicken/United_States/25-002290-001/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254548|A/chicken/United_States/25-001670-003/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254553|A/chicken/United_States/25-002096-003/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254554|A/chicken/United_States/25-002047-014/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254555|A/chicken/United_States/25-002047-006/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254556|A/chicken/United_States/25-002096-019/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254557|A/chicken/United_States/25-002096-017/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254558|A/chicken/United_States/25-002096-016/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254559|A/chicken/United_States/25-001670-002/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254560|A/chicken/United_States/25-002096-015/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254561|A/chicken/United_States/25-002096-013/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254562|A/chicken/United_States/25-002096-012/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254563|A/chicken/United_States/25-002096-011/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254564|A/chicken/United_States/25-002096-010/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254565|A/chicken/United_States/25-002096-006/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '>SRR32254566|A/chicken/United_States/25-002096-001/2025|H5N1|USA|2025|domestic_avian|D1.1\n', '> ...
