# %%
import os

# %%
genotype = "B3.13"
start_date = "11-01-2021"
end_date = "01-02-2026"

date_range = start_date + "--" + end_date

# input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/" + date_range + "/" + genotype + "/trimmed/"
# input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/"
# input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/"
input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/" + date_range + "/" + genotype + "/"
# input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--11-14-2025_Antarctica_North_America_South_America/unassigned/"


os.chdir(input_path)
sequences = {}
isolates = {}

# duplicates = {}
# output_path = input_path + "concat.fasta" # Genotype and Segment should all be the same


for dirpath, dirs, files in os.walk(input_path):
    counter = 0
    # current_header = ""
    
    for file in files:
        
        print(counter)
        file_name = os.path.join(dirpath, file)
        print(file_name)
        
        # sequences[header] = "" # Put header in list of headers to get sequences
        
        
        with open(file_name) as f:
            lines = f.readlines()
            header = ""
            isolate = ""
            for l in lines:
                # already_an_instance = False
                if l[0] == ">": # If header
                    header = l
                    isolate = header.split("|")[1]
                    if counter == 0: # and isolate in isolates.keys():

                        isolates[isolate] = header # Add isolate to list of seen isolates
                        sequences[header] = ""

                else: # If sequence
                    sequence = l
                    try:
                        sequences[header] = sequences[header] + sequence
                    except: # It's an NCBI Virus sequence whose header doesn't match the previous
                        if isolate in isolates.keys():
                            sequences[isolates[isolate]] = sequences[isolates[isolate]] + sequence
                        else:
                            print(header)
            f.close()
        counter += 1
    break 

print(sequences.keys())
print(len(sequences)) # There are different identifiers for each segment in NCBI Virus

# print(len(set(list(sequences.keys()))))

with open(input_path + genotype + "_concat_" + str(len(sequences)) + ".fasta", "w+") as o:
    for header in sequences.keys():
        # if header != "no":
        sequence = sequences[header]
        o.write(header + "\n")
        o.write(sequence + "\n")
    o.close()
# Out:
# 0
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--01-02-2026/B3.13/1-B3.13_PB2_11-01-2021--01-02-2026_aln.fasta
# 1
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--01-02-2026/B3.13/2-B3.13_PB1_11-01-2021--01-02-2026_aln.fasta
# 2
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--01-02-2026/B3.13/3-B3.13_PA_11-01-2021--01-02-2026_aln.fasta
# 3
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--01-02-2026/B3.13/4-B3.13_HA_11-01-2021--01-02-2026_aln.fasta
# 4
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--01-02-2026/B3.13/5-B3.13_NP_11-01-2021--01-02-2026_aln.fasta
# 5
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--01-02-2026/B3.13/6-B3.13_NA_11-01-2021--01-02-2026_aln.fasta
# 6
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--01-02-2026/B3.13/7-B3.13_MP_11-01-2021--01-02-2026_aln.fasta
# 7
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--01-02-2026/B3.13/8-B3.13_NS_11-01-2021--01-02-2026_aln.fasta
# dict_keys(['>EPI_ISL_19661102|A/dairy_cow/USA/038356-002/2024|H5N1|USA|2024|cattle|B3.13\n', '>EPI_ISL_19661116|A/dairy_cow/California/038274-001/2024|H5N1|USA-CA|2024-12-09|cattle|B3.13\n', '>EPI_ISL_19661063|A/serval/Washington/038180-001/2024|H5N1|USA-WA|2024-12-13|feline|B3.13\n', '>EPI_ISL_19661058|A/tiger/Colorado/038268-001/2024|H5N1|USA-CO|2024-12-18|feline|B3.13\n', '>EPI_ISL_19661059|A/lion/Colorado/038