# %%
import os

# %%
genotype = "D1.3"
start_date = "11-01-2021"
end_date = "11-28-2025"

date_range = start_date + "--" + end_date

input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/" + date_range + "/" + genotype + "/trimmed/"
# input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--09-19-2025_Antarctica_North_America_South_America/D1.1/"
# input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Data/2021-11-01--2025-10-03_Antarctica_South_America_B3_2/trimmed_alns/"
# input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/" + date_range + "/" + genotype + "/"
# input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Combinations/NCBI_Virus_Andersen_GISAID/11-01-2021--11-14-2025_Antarctica_North_America_South_America/unassigned/"


os.chdir(input_path)
sequences = {}

# output_path = input_path + "concat.fasta" # Genotype and Segment should all be the same

for dirpath, dirs, files in os.walk(input_path):
    for file in files:
        file_name = os.path.join(dirpath, file)
        print(file_name)
        header = ""
        with open(file_name) as f:
            lines = f.readlines()
            lines_list = []
            for line in lines:
                lines_list.append(line)
            for i, l in enumerate(lines_list):
                if l[0] == ">": # If header
                    header = l
                    if header not in sequences.keys():
                        sequences[header] = ""
                else: # If sequence
                    sequence = l
                    sequences[header] = sequences[header] + sequence
            f.close()
    break 

print(sequences.keys())

with open(input_path + genotype + "_concat_" + str(len(sequences)) + ".fasta", "w+") as o:
    for header in sequences:
        sequence = sequences[header]
        o.write(header + "\n")
        o.write(sequence + "\n")
    o.close()
# Out:
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--11-28-2025/D1.3/trimmed/1-D1.3_PB2_2021-11-01--2025-11-28_aln.fasta
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--11-28-2025/D1.3/trimmed/2-D1.3_PB1_2021-11-01--2025-11-28_aln.fasta
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--11-28-2025/D1.3/trimmed/3-D1.3_PA_2021-11-01--2025-11-28_aln.fasta
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--11-28-2025/D1.3/trimmed/4-D1.3_HA_2021-11-01--2025-11-28_aln.fasta
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--11-28-2025/D1.3/trimmed/5-D1.3_NP_2021-11-01--2025-11-28_aln.fasta
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--11-28-2025/D1.3/trimmed/6-D1.3_NA_2021-11-01--2025-11-28_aln.fasta
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--11-28-2025/D1.3/trimmed/7-D1.3_MP_2021-11-01--2025-11-28_aln.fasta
# C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/11-01-2021--11-28-2025/D1.3/trimmed/8-D1.3_NS_2021-11-01--2025-11-28_aln.fasta
# dict_keys(['>SRR34270369|A/Ohio/06-1/2025|H5N1|USA-OH|2025-02-12|human|D1.3\n', '>SRR33764497|A/Turkey/OH/25-005337-001-original-tile/2025|H5N1|USA-OH|2025-02-14|domestic_avian|D1.3|Darke_County_OH|Bearsmill_Farms,_LLC_(6-9)\n', '>SRR33029748|A/chicken/IN/25-010466-001-original/2025|H5N1|USA-IN|2025-03-24|domestic_avian|D1.3\n', '>SRR32973802|A/chicken/IN/25-009213-002-original/2025|H5N1|USA-IN|2025-03-16|domestic_avian|D1.3\n', '>SRR32973803|A/chicken/IN/25-009213-001-original/2025|H5N1|USA-IN|2025-03-16|domestic_avian|D1.3\n', '>SRR32973833|A/chicken/IN/25-005210-001-original-repeat2/2025|H5N1|USA-IN|2025-01-28|domestic_avian|D1.3\n', '>SRR32973832|A/chicken/IN/25-005210-002-original-repeat2/2025|H5N1|USA-IN|2025-01-28|domestic_avian|D1.3\n', '>SRR32973821|A/chicken/IN/25-005210-003-original-repeat2/2025|H5N1|USA-IN|2025-01-28|domestic_avian|D1.3\n', '>SRR33124721|A/Turkey/IN/25-006338-001-original/2025|H5N1|USA-IN|2025-02-20|domestic_avian|D1.3|Jay_County_IN|Rodney_Muhlenkamp\n', '>SRR33124719|A/Turkey/IN/25-006338-003-original/2025|H5N1|USA-IN|2025-02-20|domestic_avian|D1.3|Jay_County_IN|Rodney_Muhlenkamp\n', '>SRR33124715|A/Turkey/IN/25-006497-001-original/2025|H5N1|USA-IN|2025-02-20|domestic_avian|D1.3|Jay_County_IN|Curtis_Muhlenkamp\n', '>SRR33124720|A/Turkey/IN/25-006338-002-original/2025|H