# %%
import os

# %%
genotype = "D1.1"
# start_date = "11-01-2021"
# end_date = "08-15-2025"

# date_range = start_date + "--" + end_date

# input_path = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/Alignments/" + date_range + "/" + genotype + "/trimmed/"
input_path = "C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Other/wendy_complete_09-22-2025/aligned/"

os.chdir(input_path)
sequences = {}

# output_path = input_path + "concat.fasta" # Genotype and Segment should all be the same

for dirpath, dirs, files in os.walk(input_path):
    for file in files:
        file_name = os.path.join(dirpath, file)
        print(file_name)
        header = ""
        with open(file_name) as f:
            lines = f.readlines()
            lines_list = []
            for line in lines:
                lines_list.append(line)
            for i, l in enumerate(lines_list):
                if l[0] == ">": # If header
                    header = l
                    if header not in sequences.keys():
                        sequences[header] = ""
                else: # If sequence
                    sequence = l
                    sequences[header] = sequences[header] + sequence
            f.close()
    break 

print(sequences.keys())

with open(input_path + genotype + "_concat_" + str(len(sequences)) + ".fasta", "w+") as o:
    for header in sequences:
        sequence = sequences[header]
        o.write(header + "\n")
        o.write(sequence + "\n")
    o.close()
# Out:
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Other/wendy_complete_09-22-2025/aligned/1-D1_1_PB2_wendy_09_22_2025_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Other/wendy_complete_09-22-2025/aligned/2-D1_1_PB1_wendy_09_22_2025_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Other/wendy_complete_09-22-2025/aligned/3-D1_1_PA_wendy_09_22_2025_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Other/wendy_complete_09-22-2025/aligned/4-D1_1_HA_wendy_09_22_2025_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Other/wendy_complete_09-22-2025/aligned/5-D1_1_NP_wendy_09_22_2025_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Other/wendy_complete_09-22-2025/aligned/6-D1_1_NA_wendy_09_22_2025_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Other/wendy_complete_09-22-2025/aligned/7-D1_1_MP_wendy_09_22_2025_aln.fasta
# C:/Users/maksi/Documents/Statistics/Projects/Avian_Flu_Files/Other/wendy_complete_09-22-2025/aligned/8-D1_1_NS_wendy_09_22_2025_aln.fasta
# dict_keys(['>SRR32512599|A/Canada_goose/ME/24NE02028/2024|H5N1|USA-ME|2024-01-05|wild_avian|D1.1\n', '>SRR32868726|A/Red-tailed_hawk/MA/25MM00014/2025|H5N1|USA-MA|2025-01-30|wild_avian|D1.1\n', '>SRR32804637|A/Red-tailed_hawk/MA/24HP02050/2025|H5N1|USA-MA|2025-01-30|wild_avian|D1.1\n', '>SRR32868847|A/Bufflehead/MA/24WI00391/2025|H5N1|USA-MA|2025-02-06|wild_avian|D1.1\n', '>SRR32868720|A/Red-tailed_hawk/MA/25NE00155/2025|H5N1|USA-MA|2025-02-08|wild_avian|D1.1\n', '>SRR32512536|A/Canada_goose/MA/24MM01972/2025|H5N1|USA-MA|2025-01-22|wild_avian|D1.1\n', '>SRR35089288|A/Red-tailed_hawk/MA/24HP02051/2025|H5N1|USA-MA|2025-01-30|wild_avian|D1.1\n', '>SRR32512543|A/Canada_goose/MA/24MM01942/2025|H5N1|USA-MA|2025-01-16|wild_avian|D1.1\n', '>SRR32868852|A/Bufflehead/MA/24WI00363/2025|H5N1|USA-MA|2025-01-21|wild_avian|D1.1\n', '>SRR32254420|A/mallard_duck/MA/24MM01926/2025|H5N1|USA-MA|2025-01-12|wild_avian|D1.1\n', '>SRR32512542|A/Canada_goose/MA/24MM01946/2025|H5N1|USA-MA|2025-01-18|wild_avian|D1.1\n', '>SRR32512537|A/Canada_goose/MA/24MM01968/2025|H5N1|USA-MA|2025-01-22|wild_avian|D1.1\n', '>SRR32868888|A/Great_black-backed_gull/MA/24WI00388/2025|H5N1|USA-MA|2025-02-04|wild_avian|D1.1\n', '>SRR32868693|A/Canada_goose/MA/25NE00145/2025|H5N1|USA-MA|2025-02-05|wild_avian|D1.1\n', '>SRR32512650|A/Bald_eagle/MA/24MM01992/2025|H5N1|USA-MA|2025-01-26|wild_avian|