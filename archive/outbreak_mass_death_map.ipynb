# %% [markdown]
# # Map of Mass Death H5N1 Clade 2.3.4.4b Outbreaks in the Americas

# %%
# Housekeeping

import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
from matplotlib import pyplot
import dateutil 
from datetime import datetime, timedelta
import plotly.graph_objects as go
import importlib
import utils  
importlib.reload(utils)
from utils import * 
import plotly.express as px
import plotly

# %%
# Upload data

home = "C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/"
os.chdir(home)

mass_deaths_species = pd.read_csv("mass_deaths_south_america.csv")
mass_deaths_species["index"] = mass_deaths_species.index
mass_deaths_quants = pd.read_csv("Quantitative data 2025-08-07 Americas.csv")

mass_deaths_species.head()
# Out:
#      Country        Lat        Lon                  Species  Deaths  index
# 0  Argentina -38.419264 -63.598921   Southern elephant seal   17400      0
# 1  Argentina -38.419264 -63.598921               Thalasseus    2400      1
# 2  Argentina -38.419264 -63.598921  South American sea lion    1367      2
# 3  Argentina -38.419264 -63.598921    Puna/James's flamingo     237      3
# 4  Argentina -38.419264 -63.598921        Black-necked swan      21      4

# %%
fig = go.Figure()

fig.add_trace(go.Scattergeo(
    # name = mass_deaths_species["Species"],
    lon = mass_deaths_species["Lon"],
    lat = mass_deaths_species["Lat"],
    hoverinfo="text",
    hovertext = mass_deaths_species["index"].apply(lambda x: 
                                                   str(mass_deaths_species[mass_deaths_species["index"] == x].loc[mass_deaths_species['index'] == x, "Deaths"].iloc[0]) 
                                                   + " " + str(mass_deaths_species[mass_deaths_species["index"] == x].loc[mass_deaths_species['index'] == x, "Species"].iloc[0]) + 
                                                   " deaths, " + str(mass_deaths_species[mass_deaths_species["index"] == x].loc[mass_deaths_species['index'] == x, 'Country'].iloc[0])
                                                   if str(mass_deaths_species[mass_deaths_species["index"] == x].loc[mass_deaths_species["index"] == x, "Deaths"].iloc[0]) != "1"
                                                   else str(mass_deaths_species[mass_deaths_species["index"] == x].loc[mass_deaths_species['index'] == x, "Deaths"].iloc[0]) 
                                                   + " " + str(mass_deaths_species[mass_deaths_species["index"] == x].loc[mass_deaths_species['index'] == x, "Species"].iloc[0]) + 
                                                   " death, " + str(mass_deaths_species[mass_deaths_species["index"] == x].loc[mass_deaths_species['index'] == x, 'Country'].iloc[0])),
    showlegend=True,
    # marker_color=mass_deaths_species["Species"],
    marker = dict(
        size = mass_deaths_species["Deaths"] * 0.1,
        # color = mass_deaths_species["Species"],
        sizemode = "area"
    )))
fig.update_layout(
    
    title_text = "H5N1 Avian Influenza Mass Deaths in South America",
    legend = {"itemsizing": "trace"},
    geo = dict(
        scope = 'south america',
        landcolor = 'rgb(200, 200, 200)'
    )
)

fig.show()

plotly.offline.plot(fig, filename='C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/mass_deaths_south_america.html')
# Out:
# 'C:/Users/maksiaevai.NCBI_NT/Documents/Avian_Flu_Files/mass_deaths_south_america.html'
